# %%
from google.colab import drive
drive.mount("/content/gdrive")

# %%
# %%capture
# !pip install mne

# %% [markdown]
# # **The DATASET**

# %%
from glob import glob
import os
import mne
import numpy as np
import pandas
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
import re

# %%
ASD_file_path = glob('/content/gdrive/My Drive/MAIN PROJECT/ICCONS/ASD/*.fif')
ADHD_file_path = glob('/content/gdrive/My Drive/MAIN PROJECT/ICCONS/ADHD/*.fif')
test_ASD_file_path = glob('/content/gdrive/My Drive/MAIN PROJECT/ICCONS/test_ASD/*.fif')
test_ADHD_file_path = glob('/content/gdrive/My Drive/MAIN PROJECT/ICCONS/test_ADHD/*.fif')
print(len(ASD_file_path), len(ADHD_file_path))
print(len(test_ASD_file_path), len(test_ADHD_file_path))
# Out:
# 30 26
# 3 3

# %%
def subj_id_finder(file_path):
  pattern = r'(\w+)/(\d+)_(\d+)\.fif'
  match = re.search(pattern, file_path)
  disorder = match.group(1)
  subj_id=int(match.group(2))
  if disorder == 'ADHD':
    subj_id+=16
  return subj_id

# %%
raw = mne.io.read_raw_fif(ASD_file_path[0], preload=True)
raw
# Out:
# Opening raw data file /content/gdrive/My Drive/MAIN PROJECT/ICCONS/ASD/1_1.fif...
# Isotrak not found
#     Range : 90250 ... 489750 =    361.000 ...  1959.000 secs
# Ready.
# <ipython-input-6-4292d46f769d>:1: RuntimeWarning: This filename (/content/gdrive/My Drive/MAIN PROJECT/ICCONS/ASD/1_1.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(ASD_file_path[0], preload=True)
# Reading 0 ... 399500  =      0.000 ...  1598.000 secs...
# <Raw | 1_1.fif, 21 x 399501 (1598.0 s), ~64.0 MB, data loaded>

# %%
from scipy.signal import hann
import matplotlib.pyplot as plt
def sliding_window(file_path, l_freq=1.0, h_freq=30.0, decim_factor=2.5,test=False):

    subj_id = subj_id_finder(file_path)
    raw = mne.io.read_raw_fif(file_path, preload=True)
    raw.filter(l_freq=0.3,h_freq=30)

    data = raw.get_data()

    window_size = 2 * int(raw.info['sfreq'])
    stride = window_size// 2

    windows = []
    for i in range(0, data.shape[1] - window_size + 1, stride):
        window_data = data[:, i:i+window_size]
        # Apply a low-pass anti-aliasing filter to avoid aliasing
        #anti_alias_data = mne.filter.filter_data(window_data, sfreq=raw.info['sfreq'],  l_freq= 40 , h_freq=None,)
        hann_window = hann(window_size, sym=False)
        window_data = window_data*hann_window
        #plt.plot(window_data[20])
        # Decimate the signal
        decimated_data = mne.filter.resample(window_data, down=2.5, npad='auto')
        windows.append(decimated_data)
        if not test:
          group_list.append(subj_id)


    arr = np.array(windows)
    if len(arr)!=0:
      return arr

# %%
sample_data = sliding_window(ASD_file_path[11])
sample_data.shape
# Out:
# Opening raw data file /content/gdrive/My Drive/MAIN PROJECT/ICCONS/ASD/6_1.fif...
# Isotrak not found
#     Range : 123000 ... 126000 =    492.000 ...   504.000 secs
# Ready.
# Reading 0 ... 3000  =      0.000 ...    12.000 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.3 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.30
# - Lower transition bandwidth: 0.30 Hz (-6 dB cutoff frequency: 0.15 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 2751 samples (11.004 s)
# <ipython-input-7-119ef3b01311>:6: RuntimeWarning: This filename (/content/gdrive/My Drive/MAIN PROJECT/ICCONS/ASD/6_1.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=True)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    0.0s finished
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2913b8e65200> in <cell line: 1>()
# ----> 1 sample_data = sliding_window(ASD_file_path[11])
#       2 sample_data.shape
#
# <ipython-input-7-119ef3b01311> in sliding_window(file_path, l_freq, h_freq, decim_factor, test)
#      24         windows.append(decimated_data)
#      25         if not test:
# ---> 26           group_list.append(subj_id)
#      27
#      28
#
# NameError: name 'group_list' is not defined

# %%
# %%capture
group_list=[]
ASD_epochs_arr = [sliding_window(i) for i in ASD_file_path if sliding_window(i) is not None]
ADHD_epochs_arr = [sliding_window(i) for i in ADHD_file_path]
test_ASD_epochs_arr = [sliding_window(i,test=True) for i in test_ASD_file_path]
test_ADHD_epochs_arr = [sliding_window(i,test=True) for i in test_ADHD_file_path]

# %%
ASD_epochs_arr[1].shape,len(ASD_epochs_arr)
# Out:
# ((1597, 21, 200), 30)

# %%
ASD_epochs_labels = [len(i)*[0] for i in ASD_epochs_arr.copy()]
ADHD_epochs_labels = [len(i)*[1] for i in ADHD_epochs_arr.copy()]
test_ASD_epochs_labels = [len(i)*[0] for i in test_ASD_epochs_arr.copy()]
test_ADHD_epochs_labels = [len(i)*[1] for i in test_ADHD_epochs_arr.copy()]
len(ASD_epochs_labels),len(ADHD_epochs_labels)
# Out:
# (30, 26)

# %%
data_list = ASD_epochs_arr.copy()+ADHD_epochs_arr.copy()
ADHD_epochs_arr=0
ASD_epochs_arr=0
label_list = ASD_epochs_labels+ADHD_epochs_labels
test_data_list = test_ASD_epochs_arr.copy()+test_ADHD_epochs_arr.copy()
test_ASD_epochs_arr=0
test_ADHD_epochs_arr=0
test_label_list = test_ASD_epochs_labels+test_ADHD_epochs_labels

# %%
data_list[11]
# Out:
# array([[[ 2.09160432e-03, -2.14133773e-03,  4.76278543e-03, ...,
#           3.66077335e-02,  2.68111582e-02,  7.22818859e-04],
#         [ 3.74091178e-03, -3.57280983e-03,  1.16012824e-02, ...,
#           8.61345711e-02,  3.92778403e-02,  1.56725911e-02],
#         [ 1.94835730e-03, -2.54816661e-03, -1.91581863e-03, ...,
#           2.16720304e-02,  5.18584121e-03,  6.42211801e-03],
#         ...,
#         [ 1.41742244e-05, -1.14540856e-03, -3.22191892e-03, ...,
#           1.07336252e-01,  4.37719770e-02,  1.94257357e-02],
#         [-4.58622785e-03,  2.69882386e-03, -1.89452754e-02, ...,
#          -1.47778268e-02,  6.92708855e-03, -1.06314400e-02],
#         [-4.20534072e-03,  2.16609441e-03, -5.94059896e-03, ...,
#          -9.56849144e-02, -2.41516679e-02, -2.77188471e-02]],
#
#        [[-1.75951944e-03, -1.97243882e-02, -7.84669910e-02, ...,
#           1.03242093e-01,  2.56339949e-02,  2.56020124e-02],
#         [-1.79312957e-03, -1.51117450e-02, -6.34362681e-02, ...,
#           4.90004629e-02,  3.50854987e-02, -2.76621608e-03],
#         [ 3.43004080e-05, -1.06412146e-02, -3.94648540e-02, ...,
#           5.64600136e-02,  2.45003774e-02,  6.85189168e-03],
#         ...,
#         [ 9.28656331e-04,  7.83969765e-04,  8.31040628e-03, ...,
#           3.73747901e-02,  8.47478989e-04,  1.07198230e-02],
#         [ 1.65175143e-03,  9.66034934e-03,  4.21265733e-02, ...,
#           1.26387649e-02, -1.29032112e-02,  1.00371819e-02],
#         [-3.86630870e-03,  1.24948587e-02,  2.55640473e-02, ...,
#          -4.95843273e-04,  5.08817243e-03, -5.18527816e-03]],
#
#        [[-2.89878615e-04,  6.54590065e-03,  1.06701235e-02, ...,
#          -7.25811978e-02, -6.26614818e-02,  5.93905844e-03],
#         [ 8.08897683e-04,  1.26248583e-02,  4.81636977e-02, ...,
#          -1.11378044e-01, -5.49936291e-02, -1.10661750e-02],
#         [ 1.90313369e-03,  4.38762755e-04,  7.16046986e-03, ...,
#          -7.78348101e-03, -2.34869807e-02,  7.62034597e-03],
#         ...,
#         [-4.34323607e-04,  1.18957575e-02,  4.10955632e-02, ...,
#          -6.75346692e-02, -4.83401996e-02, -1.33135691e-03],
#         [-3.13818466e-04, -1.22738204e-03,  2.68735105e-04, ...,
#           8.51796658e-02,  4.96639270e-02,  7.41206537e-04],
#         [-7.61914425e-04, -8.78298120e-03, -3.34091239e-02, ...,
#           1.24712862e-01,  4.69689106e-02,  2.80539415e-02]],
#
#        ...,
#
#        [[-4.62449599e-03, -5.47638632e-03, -3.20619884e-02, ...,
#          -3.26408062e-03,  1.41180346e-02, -3.83118017e-03],
#         [-2.93468865e-04, -5.34344335e-03, -2.05525763e-02, ...,
#          -1.75979403e-02, -4.74796168e-04,  3.87630038e-03],
#         [-2.16206819e-04, -6.09272191e-03, -2.19171184e-02, ...,
#          -4.64712510e-02, -2.79427208e-02, -1.74403998e-03],
#         ...,
#         [-1.05339240e-03, -7.01685053e-03, -2.90840404e-02, ...,
#          -7.93682568e-02, -4.18657806e-02, -8.71338451e-03],
#         [ 8.84653972e-03,  3.92558256e-03,  4.66022695e-02, ...,
#           5.63982908e-02, -4.35281532e-02,  4.28544246e-02],
#         [ 2.55508675e-03,  1.61393980e-02,  5.72403808e-02, ...,
#          -4.22647940e-02, -3.49508186e-02,  3.81720321e-03]],
#
#        [[-5.94394039e-03,  3.20039608e-03, -9.97982917e-03, ...,
#           6.36882948e-04,  1.67597761e-02, -1.99696733e-02],
#         [-1.87022261e-03, -3.29520549e-03, -1.64486138e-02, ...,
#           1.15502605e-02,  3.59659976e-02, -2.60794526e-02],
#         [ 1.96542700e-03,  4.53489486e-03,  2.69621758e-02, ...,
#          -3.35440777e-02, -3.37201573e-02,  4.74142160e-03],
#         ...,
#         [ 3.28075065e-03,  5.02747868e-03,  3.57952759e-02, ...,
#          -4.77473070e-02, -2.95444019e-02, -4.30808654e-03],
#         [ 4.19996209e-03, -7.78828109e-03, -2.09450800e-02, ...,
#           1.95003772e-02, -3.45185214e-02,  3.01668772e-02],
#         [ 3.98404450e-03, -2.45235221e-03,  2.41101935e-03, ...,
#           2.05463734e-02,  3.05145630e-03,  1.06854692e-02]],
#
#        [[ 2.59969837e-03,  4.66998881e-04,  1.89512359e-02, ...,
#           9.60847739e-03, -1.40529189e-03,  2.95568234e-03],
#         [-6.83166004e-04,  1.85483992e-03,  6.51754560e-03, ...,
#           2.36545579e-02,  5.15126164e-06,  5.89646907e-03],
#         [-1.55115746e-03, -2.90275058e-03, -1.12182261e-02, ...,
#          -1.33833299e-02, -3.19895992e-03, -9.97591667e-04],
#         ...,
#         [-1.65008088e-03, -8.57616895e-03, -4.07960215e-02, ...,
#           5.12906678e-03,  8.25881829e-03, -9.15669891e-03],
#         [-6.39587116e-03, -1.30095628e-03, -4.15074259e-02, ...,
#          -3.14774983e-02,  4.77942441e-02, -4.23924031e-02],
#         [-1.64065288e-04, -7.56984633e-03, -3.21928978e-02, ...,
#          -3.59549246e-02, -1.34351395e-04, -5.01558555e-03]]])

# %%
print(len(data_list))
len(group_list),len(label_list)
# Out:
# 56
# (57898, 56)

# %%
train_features = np.vstack(data_list)
test_features = np.vstack(test_data_list)
label_arr = np.hstack(label_list)
test_labels = np.hstack(test_label_list)
group_arr =np.hstack(group_list)

# %%
group_arr.shape,train_features.shape,label_arr.shape
# Out:
# ((57898,), (36310, 21, 200), (36310,))

# %%
group_arr
# Out:
# array([ 1,  1,  1, ..., 31, 31, 31])

# %%
test_features = np.moveaxis(test_features,1,2)
test_features.shape
train_features = np.moveaxis(train_features,1,2)
train_features.shape
# Out:
# (36310, 200, 21)

# %%
data_list=0
test_data_list=0
label_list=0
test_label_list=0

# %%
label_arr
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
train_labels = label_arr.copy()

# %%
train_labels.shape
# Out:
# (36310,)

# %%
# from sklearn.preprocessing import StandardScaler
# scaler =  StandardScaler()
# test_features=scaler.fit_transform(test_data.reshape(-1,\
#                     test_data.shape[-1])).reshape(test_data.shape)

# %% [markdown]
# ## **Train-Test split**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GroupKFold, LeaveOneGroupOut
scaler =  StandardScaler()
gkf=GroupKFold(n_splits=5)

# %%
train_index, val_index = gkf.split(data_arr, label_arr, groups=group_arr)
val_index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-309e66190c6c> in <cell line: 1>()
# ----> 1 train_index, val_index = gkf.split(data_arr, label_arr, groups=group_arr)
#       2 val_index
#
# NameError: name 'data_arr' is not defined

# %%
train_data, val_data, train_labels, val_labels = train_test_split(data_arr, label_arr, test_size=0.2,
                                                                        random_state=42, stratify=label_arr)

# %%
# Use GroupKFold to split the data into training and validation sets
co=0
for train_index, val_index in gkf.split(data_arr, label_arr, groups=group_arr):
    # Use the train_index and val_index to create the training and validation sets
    train_data = data_arr[train_index]
    train_labels = label_arr[train_index]
    test_data = data_arr[val_index]
    test_labels = label_arr[val_index]
    print(val_index)
    co+=1
    print(co)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-b32fa90bf8be> in <cell line: 3>()
#       1 # Use GroupKFold to split the data into training and validation sets
#       2 co=0
# ----> 3 for train_index, val_index in gkf.split(data_arr, label_arr, groups=group_arr):
#       4     # Use the train_index and val_index to create the training and validation sets
#       5     train_data = data_arr[train_index]
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#     340             The testing set indices for that split.
#     341         """
# --> 342         X, y, groups = indexable(X, y, groups)
#     343         n_samples = _num_samples(X)
#     344         if self.n_splits > n_samples:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     441
#     442     result = [_make_indexable(X) for X in iterables]
# --> 443     check_consistent_length(*result)
#     444     return result
#     445
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
# --> 397         raise ValueError(
#     398             "Found input variables with inconsistent numbers of samples: %r"
#     399             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [7195, 7195, 8531]

# %%
train_data = data_arr[train_index[0]]
train_labels = label_arr[train_index[0]]
val_data = data_arr[val_index[0]]
val_labels = label_arr[val_index[0]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-d06aed1ce755> in <cell line: 1>()
# ----> 1 train_data = data_arr[train_index[0]]
#       2 train_labels = label_arr[train_index[0]]
#       3 val_data = data_arr[val_index[0]]
#       4 val_labels = label_arr[val_index[0]]
#
# NameError: name 'train_index' is not defined

# %%
train_data = np.moveaxis(train_data,1,2)
val_data  = np.moveaxis(val_data,1,2)

# %%
val_data.shape
# Out:
# (3598, 1000, 21)

# %%
val_labels
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
train_features=scaler.fit_transform(train_features.reshape(-1,\
                    train_features.shape[-1])).reshape(train_features.shape)
#val_features=scaler.transform(val_data.reshape(-1,\
#                   val_data.shape[-1])).reshape(val_data.shape)
test_features=scaler.fit_transform(test_features.reshape(-1,\
                    test_features.shape[-1])).reshape(test_features.shape)

# %%
train_data=[]
test_data=[]

# %% [markdown]
# # **CNN Model_1**

# %%
from tensorflow.keras.layers import Conv1D,BatchNormalization,LeakyReLU,MaxPool1D,\
GlobalAveragePooling1D,Dense,Dropout,AveragePooling1D,ReLU,MaxPooling1D,InputLayer,Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.backend import clear_session
from tensorflow.keras.utils import plot_model
import keras.backend as K
K.clear_session()

# %%
def cnnmodel():
  clear_session()
  model=Sequential()
  model.add(Conv1D(filters=5,kernel_size=3,strides=1,input_shape=(700,21)))#1
  model.add(BatchNormalization())
  model.add(LeakyReLU())
  model.add(MaxPool1D(pool_size=2,strides=2))#2
  model.add(Conv1D(filters=5,kernel_size=3,strides=1))#3
  model.add(LeakyReLU())
  model.add(MaxPool1D(pool_size=2,strides=2))#4
  model.add(Dropout(0.5))
  model.add(Conv1D(filters=5,kernel_size=3,strides=1))#5
  model.add(LeakyReLU())
  model.add(AveragePooling1D(pool_size=2,strides=2))#6
  model.add(Dropout(0.5))
  model.add(Conv1D(filters=5,kernel_size=3,strides=1))#7
  model.add(LeakyReLU())
  model.add(AveragePooling1D(pool_size=2,strides=2))#8
  model.add(Conv1D(filters=5,kernel_size=3,strides=1))#9
  model.add(LeakyReLU())
  model.add(GlobalAveragePooling1D())#10
  model.add(Dense(1,activation='sigmoid'))#11

  model.compile('adam',loss='binary_crossentropy',metrics=['accuracy'])
  return model
# def cnnmodel():
#   clear_session()
#   model=Sequential()
#   model.add(Conv1D(filters=10,kernel_size=5,strides=1,input_shape=(200,21)))#1
#   model.add(BatchNormalization())
#   model.add(LeakyReLU())
#   model.add(MaxPool1D(pool_size=2,strides=2))#2
#   model.add(Conv1D(filters=20,kernel_size=3,strides=1))#3
#   model.add(LeakyReLU())
#   model.add(MaxPool1D(pool_size=2,strides=2))#4
#   model.add(Dropout(0.5))
#   model.add(Conv1D(filters=30,kernel_size=3,strides=1))#5
#   model.add(LeakyReLU())
#   model.add(AveragePooling1D(pool_size=2,strides=2))#6
#   model.add(Dropout(0.5))
#   model.add(Conv1D(filters=40,kernel_size=3,strides=1))#7
#   model.add(ReLU())
#   model.add(AveragePooling1D(pool_size=2,strides=2))#8
#   model.add(Conv1D(filters=50,kernel_size=3,strides=1))#9
#   model.add(ReLU())
#   model.add(GlobalAveragePooling1D())#10
#   model.add(Dense(64,activation='relu'))#11
#   model.add(Dropout(0.5))
#   model.add(Dense(1,activation='sigmoid'))#12

#   model.compile('adam',loss='binary_crossentropy',metrics=['accuracy'])
#   return model
model=cnnmodel()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 196, 10)           1060
#
#  batch_normalization (BatchN  (None, 196, 10)          40
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 196, 10)           0
#
#  max_pooling1d (MaxPooling1D  (None, 98, 10)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 96, 20)            620
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 96, 20)            0
#
#  max_pooling1d_1 (MaxPooling  (None, 48, 20)           0
#  1D)
#
#  dropout (Dropout)           (None, 48, 20)            0
#
#  conv1d_2 (Conv1D)           (None, 46, 30)            1830
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 46, 30)            0
#
#  average_pooling1d (AverageP  (None, 23, 30)           0
#  ooling1D)
#
#  dropout_1 (Dropout)         (None, 23, 30)            0
#
#  conv1d_3 (Conv1D)           (None, 21, 40)            3640
#
#  re_lu (ReLU)                (None, 21, 40)            0
#
#  average_pooling1d_1 (Averag  (None, 10, 40)           0
#  ePooling1D)
#
#  conv1d_4 (Conv1D)           (None, 8, 50)             6050
#
#  re_lu_1 (ReLU)              (None, 8, 50)             0
#
#  global_average_pooling1d (G  (None, 50)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 64)                3264
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 16,569
# Trainable params: 16,549
# Non-trainable params: 20
# _________________________________________________________________

# %%
history = model.fit(train_features,train_labels,epochs=40,batch_size=16,validation_data=(test_features,test_labels))
# Out:
# Epoch 1/40
# 2270/2270 [==============================] - 52s 17ms/step - loss: 0.3695 - accuracy: 0.8338 - val_loss: 1.0583 - val_accuracy: 0.5322
# Epoch 2/40
# 2270/2270 [==============================] - 37s 16ms/step - loss: 0.2620 - accuracy: 0.8917 - val_loss: 1.1887 - val_accuracy: 0.5501
# Epoch 3/40
# 2270/2270 [==============================] - 36s 16ms/step - loss: 0.2193 - accuracy: 0.9106 - val_loss: 1.2451 - val_accuracy: 0.5354
# Epoch 4/40
# 2270/2270 [==============================] - 37s 17ms/step - loss: 0.1912 - accuracy: 0.9225 - val_loss: 1.2473 - val_accuracy: 0.5498
# Epoch 5/40
# 2270/2270 [==============================] - 39s 17ms/step - loss: 0.1624 - accuracy: 0.9348 - val_loss: 1.4463 - val_accuracy: 0.5468
# Epoch 6/40
# 2270/2270 [==============================] - 36s 16ms/step - loss: 0.1408 - accuracy: 0.9451 - val_loss: 1.2801 - val_accuracy: 0.5534
# Epoch 7/40
# 2270/2270 [==============================] - 38s 17ms/step - loss: 0.1267 - accuracy: 0.9499 - val_loss: 1.5463 - val_accuracy: 0.5546
# Epoch 8/40
# 2270/2270 [==============================] - 36s 16ms/step - loss: 0.1180 - accuracy: 0.9533 - val_loss: 1.5905 - val_accuracy: 0.5595
# Epoch 9/40
# 2270/2270 [==============================] - 37s 16ms/step - loss: 0.1051 - accuracy: 0.9594 - val_loss: 1.4773 - val_accuracy: 0.5529
# Epoch 10/40
# 2270/2270 [==============================] - 38s 17ms/step - loss: 0.0940 - accuracy: 0.9629 - val_loss: 1.8109 - val_accuracy: 0.5506
# Epoch 11/40
# 2270/2270 [==============================] - 36s 16ms/step - loss: 0.0836 - accuracy: 0.9668 - val_loss: 1.6508 - val_accuracy: 0.5695
# Epoch 12/40
# 2270/2270 [==============================] - 37s 16ms/step - loss: 0.0784 - accuracy: 0.9697 - val_loss: 1.8881 - val_accuracy: 0.5540
# Epoch 13/40
# 2270/2270 [==============================] - 36s 16ms/step - loss: 0.0724 - accuracy: 0.9720 - val_loss: 1.7802 - val_accuracy: 0.5689
# Epoch 14/40
# 2270/2270 [==============================] - 37s 16ms/step - loss: 0.0691 - accuracy: 0.9738 - val_loss: 1.8767 - val_accuracy: 0.5458
# Epoch 15/40
# 2270/2270 [==============================] - 39s 17ms/step - loss: 0.0656 - accuracy: 0.9755 - val_loss: 1.6367 - val_accuracy: 0.5663
# Epoch 16/40
# 2270/2270 [==============================] - 36s 16ms/step - loss: 0.0629 - accuracy: 0.9758 - val_loss: 1.9800 - val_accuracy: 0.5623
# Epoch 17/40
# 2270/2270 [==============================] - 37s 17ms/step - loss: 0.0588 - accuracy: 0.9777 - val_loss: 2.0123 - val_accuracy: 0.5632
# Epoch 18/40
# 2270/2270 [==============================] - 36s 16ms/step - loss: 0.0548 - accuracy: 0.9787 - val_loss: 2.2915 - val_accuracy: 0.5573
# Epoch 19/40
# 2270/2270 [==============================] - 37s 16ms/step - loss: 0.0584 - accuracy: 0.9782 - val_loss: 1.9297 - val_accuracy: 0.5546
# Epoch 20/40
# 2270/2270 [==============================] - 39s 17ms/step - loss: 0.0523 - accuracy: 0.9801 - val_loss: 2.0114 - val_accuracy: 0.5504
# Epoch 21/40
# 2270/2270 [==============================] - 36s 16ms/step - loss: 0.0522 - accuracy: 0.9799 - val_loss: 2.1632 - val_accuracy: 0.5659
# Epoch 22/40
# 2270/2270 [==============================] - 37s 16ms/step - loss: 0.0523 - accuracy: 0.9803 - val_loss: 2.1240 - val_accuracy: 0.5613
# Epoch 23/40
# 2270/2270 [==============================] - 37s 16ms/step - loss: 0.0483 - accuracy: 0.9815 - val_loss: 2.2395 - val_accuracy: 0.5456
# Epoch 24/40
# 2270/2270 [==============================] - 36s 16ms/step - loss: 0.0454 - accuracy: 0.9827 - val_loss: 2.2119 - val_accuracy: 0.5413
# Epoch 25/40
# 2270/2270 [==============================] - 38s 17ms/step - loss: 0.0465 - accuracy: 0.9824 - val_loss: 1.9540 - val_accuracy: 0.5647
# Epoch 26/40
# 2270/2270 [==============================] - 36s 16ms/step - loss: 0.0446 - accuracy: 0.9830 - val_loss: 2.2271 - val_accuracy: 0.5729
# Epoch 27/40
# 2270/2270 [==============================] - 37s 16ms/step - loss: 0.0491 - accuracy: 0.9817 - val_loss: 1.8860 - val_accuracy: 0.5826
# Epoch 28/40
# 2270/2270 [==============================] - 39s 17ms/step - loss: 0.0435 - accuracy: 0.9831 - val_loss: 2.2106 - val_accuracy: 0.5541
# Epoch 29/40
# 2270/2270 [==============================] - 36s 16ms/step - loss: 0.0459 - accuracy: 0.9829 - val_loss: 2.1804 - val_accuracy: 0.5690
# Epoch 30/40
# 2270/2270 [==============================] - 37s 16ms/step - loss: 0.0409 - accuracy: 0.9839 - val_loss: 2.0664 - val_accuracy: 0.5873
# Epoch 31/40
# 2270/2270 [==============================] - 36s 16ms/step - loss: 0.0437 - accuracy: 0.9822 - val_loss: 2.1472 - val_accuracy: 0.5832
# Epoch 32/40
# 2270/2270 [==============================] - 36s 16ms/step - loss: 0.0432 - accuracy: 0.9835 - val_loss: 1.9588 - val_accuracy: 0.5790
# Epoch 33/40
# 2270/2270 [==============================] - 39s 17ms/step - loss: 0.0413 - accuracy: 0.9842 - val_loss: 2.3149 - val_accuracy: 0.5809
# Epoch 34/40
# 2270/2270 [==============================] - 36s 16ms/step - loss: 0.0414 - accuracy: 0.9850 - val_loss: 2.4455 - val_accuracy: 0.5604
# Epoch 35/40
# 2270/2270 [==============================] - 38s 17ms/step - loss: 0.0421 - accuracy: 0.9843 - val_loss: 2.0404 - val_accuracy: 0.5644
# Epoch 36/40
# 2270/2270 [==============================] - 37s 16ms/step - loss: 0.0423 - accuracy: 0.9838 - val_loss: 2.2772 - val_accuracy: 0.5695
# Epoch 37/40
# 2270/2270 [==============================] - 36s 16ms/step - loss: 0.0381 - accuracy: 0.9858 - val_loss: 2.3713 - val_accuracy: 0.5553
# Epoch 38/40
# 2270/2270 [==============================] - 37s 16ms/step - loss: 0.0401 - accuracy: 0.9855 - val_loss: 2.2003 - val_accuracy: 0.5458
# Epoch 39/40
# 2270/2270 [==============================] - 36s 16ms/step - loss: 0.0426 - accuracy: 0.9837 - val_loss: 2.1219 - val_accuracy: 0.5778
# Epoch 40/40
# 2270/2270 [==============================] - 38s 17ms/step - loss: 0.0437 - accuracy: 0.9837 - val_loss: 2.0676 - val_accuracy: 0.5555

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Curves')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-31c391bc9647> in <cell line: 2>()
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(history.history['loss'], label='Training Loss')
#       3 plt.plot(history.history['val_loss'], label='Validation Loss')
#       4 plt.title('Training and Validation Loss Curves')
#       5 plt.xlabel('Epoch')
#
# NameError: name 'history' is not defined

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy Curves')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # **ChroNet**

# %%
from tensorflow.keras.layers import Input,Dense,concatenate,Flatten,GRU,Conv1D
from tensorflow.keras.models import Model

# %%
def block(input):
  conv1 = Conv1D(filters=32,kernel_size=2,strides=2,activation='relu',padding='causal')(input)
  conv2 = Conv1D(filters=32,kernel_size=4,strides=2,activation='relu',padding='causal')(input)
  conv3 = Conv1D(filters=32,kernel_size=8,strides=2,activation='relu',padding='causal')(input)
  x = concatenate([conv1,conv2,conv3],axis=2)
  return x

# %%
input = Input(shape=(200, 21))
block1 = block(input)
block1.shape
# Out:
# TensorShape([None, 100, 96])

# %%
block2 = block(block1)
block3 = block(block2)
block3.shape
# Out:
# TensorShape([None, 25, 96])

# %%
gru1 = GRU(units=32,return_sequences=True)(block3)
gru2 = GRU(units=32,return_sequences=True)(gru1)
gru_out = concatenate([gru1,gru2],axis=2)

gru3 = GRU(units=32,return_sequences=True)(gru_out)
gru_out = concatenate([gru1,gru2,gru3],axis=2)
gru_out.shape
# Out:
# TensorShape([None, 25, 96])

# %%
gru4 = GRU(units=32)(gru_out)
out2 = Dense(16,activation='relu')(gru4)
out = Dense(1,activation='sigmoid')(out2)

# %%
model = Model(inputs=input,outputs=out)
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
val_accs = []
his_Tacc=[]
his_Vacc=[]
his_Tloss=[]
his_Vloss=[]
for train_index, val_index in gkf.split(train_features, train_labels, groups=group_arr):
    # Use the train_index and val_index to create the training and validation sets
    train_data = train_features[train_index]

    train_label = train_labels[train_index]
    test_data = train_features[val_index]
    test_label = train_labels[val_index]

    history = model.fit(train_data,train_label,epochs=10,batch_size=32,validation_data=(test_data,test_label))

    his_Tloss.append(history.history['loss'])
    his_Vloss.append(history.history['val_loss'])
    his_Tacc.append(history.history['accuracy'])
    his_Vacc.append(history.history['val_accuracy'])


    val_accs.append(history.history['val_accuracy'][-1])

print('Average validation accuracy:', sum(val_accs) / len(val_accs))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-30b5e398b0e8> in <cell line: 6>()
#       4 his_Tloss=[]
#       5 his_Vloss=[]
# ----> 6 for train_index, val_index in gkf.split(train_features, train_labels, groups=group_arr):
#       7     # Use the train_index and val_index to create the training and validation sets
#       8     train_data = train_features[train_index]
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#     340             The testing set indices for that split.
#     341         """
# --> 342         X, y, groups = indexable(X, y, groups)
#     343         n_samples = _num_samples(X)
#     344         if self.n_splits > n_samples:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     441
#     442     result = [_make_indexable(X) for X in iterables]
# --> 443     check_consistent_length(*result)
#     444     return result
#     445
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
# --> 397         raise ValueError(
#     398             "Found input variables with inconsistent numbers of samples: %r"
#     399             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [3185, 3185, 5081]

# %% [markdown]
# # **v3**

# %%
model = Sequential()
model.add(InputLayer(input_shape=(200, 21)))
model.add(Conv1D(64, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())
model.add(Conv1D(64, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())
model.add(Conv1D(128, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())
model.add(Conv1D(128, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())
model.add(Conv1D(256, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.compile('adam',loss='binary_crossentropy',metrics=['accuracy'])
#history = model.fit(train_features,train_labels,epochs=50,batch_size=32,validation_data=(test_features,test_labels))

# %%
plot_model(model, to_file="my_model.png", show_shapes=True)

# %%
val_accs = []
his_Tacc=[]
his_Vacc=[]
his_Tloss=[]
his_Vloss=[]
for train_index, val_index in gkf.split(train_features, train_labels, groups=group_arr):
    # Use the train_index and val_index to create the training and validation sets
    train_data = train_features[train_index]

    train_label = train_labels[train_index]
    #test_data = train_features[val_index]
    #test_label = train_labels[val_index]

    history = model.fit(train_data,train_label,epochs=100,batch_size=128,validation_data=(test_features,test_labels))

    his_Tloss.append(history.history['loss'])
    his_Vloss.append(history.history['val_loss'])
    his_Tacc.append(history.history['accuracy'])
    his_Vacc.append(history.history['val_accuracy'])


    val_accs.append(history.history['val_accuracy'][-1])

print('Average validation accuracy:', sum(val_accs) / len(val_accs))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-925fda8d3532> in <cell line: 6>()
#       4 his_Tloss=[]
#       5 his_Vloss=[]
# ----> 6 for train_index, val_index in gkf.split(train_features, train_labels, groups=group_arr):
#       7     # Use the train_index and val_index to create the training and validation sets
#       8     train_data = train_features[train_index]
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#     340             The testing set indices for that split.
#     341         """
# --> 342         X, y, groups = indexable(X, y, groups)
#     343         n_samples = _num_samples(X)
#     344         if self.n_splits > n_samples:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     441
#     442     result = [_make_indexable(X) for X in iterables]
# --> 443     check_consistent_length(*result)
#     444     return result
#     445
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
# --> 397         raise ValueError(
#     398             "Found input variables with inconsistent numbers of samples: %r"
#     399             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [72564, 72564, 115710]

# %%
history = model.fit(train_features,train_labels,epochs=100,batch_size=64,validation_data=(test_features,test_labels))
# Out:
# Epoch 1/100
# 568/568 [==============================] - 9s 15ms/step - loss: 0.0510 - accuracy: 0.9819 - val_loss: 1.7287 - val_accuracy: 0.6438
# Epoch 2/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0386 - accuracy: 0.9868 - val_loss: 1.9779 - val_accuracy: 0.6415
# Epoch 3/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0389 - accuracy: 0.9868 - val_loss: 1.6723 - val_accuracy: 0.6494
# Epoch 4/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0349 - accuracy: 0.9877 - val_loss: 2.3411 - val_accuracy: 0.6176
# Epoch 5/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0314 - accuracy: 0.9889 - val_loss: 3.1809 - val_accuracy: 0.6092
# Epoch 6/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0326 - accuracy: 0.9891 - val_loss: 1.9614 - val_accuracy: 0.6640
# Epoch 7/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0322 - accuracy: 0.9886 - val_loss: 2.1495 - val_accuracy: 0.6439
# Epoch 8/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0311 - accuracy: 0.9886 - val_loss: 1.6650 - val_accuracy: 0.6572
# Epoch 9/100
# 568/568 [==============================] - 8s 14ms/step - loss: 0.0276 - accuracy: 0.9902 - val_loss: 2.0725 - val_accuracy: 0.6575
# Epoch 10/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0281 - accuracy: 0.9902 - val_loss: 2.0220 - val_accuracy: 0.6694
# Epoch 11/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0278 - accuracy: 0.9901 - val_loss: 2.0339 - val_accuracy: 0.6353
# Epoch 12/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0241 - accuracy: 0.9915 - val_loss: 1.8861 - val_accuracy: 0.6573
# Epoch 13/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0265 - accuracy: 0.9908 - val_loss: 2.0290 - val_accuracy: 0.6529
# Epoch 14/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0265 - accuracy: 0.9906 - val_loss: 2.6464 - val_accuracy: 0.6337
# Epoch 15/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0208 - accuracy: 0.9930 - val_loss: 3.3024 - val_accuracy: 0.6183
# Epoch 16/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0209 - accuracy: 0.9931 - val_loss: 2.9127 - val_accuracy: 0.6480
# Epoch 17/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0225 - accuracy: 0.9925 - val_loss: 3.0464 - val_accuracy: 0.6344
# Epoch 18/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0256 - accuracy: 0.9912 - val_loss: 3.5996 - val_accuracy: 0.6314
# Epoch 19/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0200 - accuracy: 0.9937 - val_loss: 2.6558 - val_accuracy: 0.6454
# Epoch 20/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0229 - accuracy: 0.9922 - val_loss: 2.5427 - val_accuracy: 0.6673
# Epoch 21/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0199 - accuracy: 0.9930 - val_loss: 2.3596 - val_accuracy: 0.6439
# Epoch 22/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0217 - accuracy: 0.9932 - val_loss: 2.4745 - val_accuracy: 0.6614
# Epoch 23/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0195 - accuracy: 0.9938 - val_loss: 2.1109 - val_accuracy: 0.6459
# Epoch 24/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0215 - accuracy: 0.9933 - val_loss: 2.2019 - val_accuracy: 0.6408
# Epoch 25/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0159 - accuracy: 0.9952 - val_loss: 2.5419 - val_accuracy: 0.6657
# Epoch 26/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0179 - accuracy: 0.9942 - val_loss: 2.2006 - val_accuracy: 0.6468
# Epoch 27/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0205 - accuracy: 0.9936 - val_loss: 2.7823 - val_accuracy: 0.6387
# Epoch 28/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0149 - accuracy: 0.9954 - val_loss: 2.2432 - val_accuracy: 0.6398
# Epoch 29/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0154 - accuracy: 0.9948 - val_loss: 2.3677 - val_accuracy: 0.6499
# Epoch 30/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0133 - accuracy: 0.9956 - val_loss: 3.9608 - val_accuracy: 0.6335
# Epoch 31/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0184 - accuracy: 0.9936 - val_loss: 2.1652 - val_accuracy: 0.6533
# Epoch 32/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0245 - accuracy: 0.9927 - val_loss: 2.2575 - val_accuracy: 0.6618
# Epoch 33/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0143 - accuracy: 0.9953 - val_loss: 2.0863 - val_accuracy: 0.6713
# Epoch 34/100
# 568/568 [==============================] - 8s 13ms/step - loss: 0.0146 - accuracy: 0.9952 - val_loss: 2.4088 - val_accuracy: 0.6695
# Epoch 35/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0154 - accuracy: 0.9957 - val_loss: 2.9689 - val_accuracy: 0.6491
# Epoch 36/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 2.9303 - val_accuracy: 0.6584
# Epoch 37/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0184 - accuracy: 0.9946 - val_loss: 2.6549 - val_accuracy: 0.6645
# Epoch 38/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0145 - accuracy: 0.9951 - val_loss: 3.2303 - val_accuracy: 0.6620
# Epoch 39/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0142 - accuracy: 0.9956 - val_loss: 2.5019 - val_accuracy: 0.6675
# Epoch 40/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0167 - accuracy: 0.9945 - val_loss: 2.4404 - val_accuracy: 0.6813
# Epoch 41/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0115 - accuracy: 0.9963 - val_loss: 4.4238 - val_accuracy: 0.6182
# Epoch 42/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0167 - accuracy: 0.9952 - val_loss: 2.8348 - val_accuracy: 0.6474
# Epoch 43/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0128 - accuracy: 0.9963 - val_loss: 2.5196 - val_accuracy: 0.6462
# Epoch 44/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0167 - accuracy: 0.9947 - val_loss: 3.6486 - val_accuracy: 0.6374
# Epoch 45/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0145 - accuracy: 0.9957 - val_loss: 2.7602 - val_accuracy: 0.6506
# Epoch 46/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0136 - accuracy: 0.9961 - val_loss: 3.1062 - val_accuracy: 0.6386
# Epoch 47/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0149 - accuracy: 0.9951 - val_loss: 3.5638 - val_accuracy: 0.6500
# Epoch 48/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0130 - accuracy: 0.9961 - val_loss: 3.4944 - val_accuracy: 0.6493
# Epoch 49/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0109 - accuracy: 0.9970 - val_loss: 3.7150 - val_accuracy: 0.6298
# Epoch 50/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0148 - accuracy: 0.9952 - val_loss: 3.5905 - val_accuracy: 0.6468
# Epoch 51/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0133 - accuracy: 0.9954 - val_loss: 2.6475 - val_accuracy: 0.6527
# Epoch 52/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0127 - accuracy: 0.9965 - val_loss: 2.9200 - val_accuracy: 0.6407
# Epoch 53/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0123 - accuracy: 0.9959 - val_loss: 3.5139 - val_accuracy: 0.6445
# Epoch 54/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0111 - accuracy: 0.9965 - val_loss: 3.8587 - val_accuracy: 0.6395
# Epoch 55/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 3.0780 - val_accuracy: 0.6405
# Epoch 56/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0131 - accuracy: 0.9958 - val_loss: 3.7539 - val_accuracy: 0.6247
# Epoch 57/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0134 - accuracy: 0.9951 - val_loss: 3.2331 - val_accuracy: 0.6524
# Epoch 58/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0109 - accuracy: 0.9966 - val_loss: 3.1966 - val_accuracy: 0.6694
# Epoch 59/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0128 - accuracy: 0.9962 - val_loss: 3.0333 - val_accuracy: 0.6253
# Epoch 60/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0110 - accuracy: 0.9964 - val_loss: 3.5313 - val_accuracy: 0.6460
# Epoch 61/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0110 - accuracy: 0.9966 - val_loss: 3.6745 - val_accuracy: 0.6247
# Epoch 62/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0090 - accuracy: 0.9969 - val_loss: 5.0831 - val_accuracy: 0.6347
# Epoch 63/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0135 - accuracy: 0.9958 - val_loss: 3.2623 - val_accuracy: 0.6618
# Epoch 64/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0147 - accuracy: 0.9958 - val_loss: 2.6759 - val_accuracy: 0.6684
# Epoch 65/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0123 - accuracy: 0.9963 - val_loss: 4.1594 - val_accuracy: 0.6481
# Epoch 66/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0093 - accuracy: 0.9972 - val_loss: 4.0656 - val_accuracy: 0.6411
# Epoch 67/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0145 - accuracy: 0.9961 - val_loss: 3.4067 - val_accuracy: 0.6290
# Epoch 68/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0116 - accuracy: 0.9966 - val_loss: 4.4745 - val_accuracy: 0.6295
# Epoch 69/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0105 - accuracy: 0.9965 - val_loss: 2.6688 - val_accuracy: 0.6576
# Epoch 70/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0095 - accuracy: 0.9972 - val_loss: 3.9833 - val_accuracy: 0.6500
# Epoch 71/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0156 - accuracy: 0.9954 - val_loss: 4.6144 - val_accuracy: 0.6226
# Epoch 72/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0095 - accuracy: 0.9972 - val_loss: 3.4722 - val_accuracy: 0.6541
# Epoch 73/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0108 - accuracy: 0.9967 - val_loss: 2.9407 - val_accuracy: 0.6627
# Epoch 74/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 3.5531 - val_accuracy: 0.6615
# Epoch 75/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0095 - accuracy: 0.9969 - val_loss: 4.6227 - val_accuracy: 0.6313
# Epoch 76/100
# 568/568 [==============================] - 8s 13ms/step - loss: 0.0103 - accuracy: 0.9967 - val_loss: 3.7093 - val_accuracy: 0.6558
# Epoch 77/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0128 - accuracy: 0.9964 - val_loss: 3.2264 - val_accuracy: 0.6444
# Epoch 78/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0190 - accuracy: 0.9939 - val_loss: 3.2226 - val_accuracy: 0.6692
# Epoch 79/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0079 - accuracy: 0.9975 - val_loss: 2.9925 - val_accuracy: 0.6888
# Epoch 80/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0074 - accuracy: 0.9978 - val_loss: 3.8335 - val_accuracy: 0.6480
# Epoch 81/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 2.7398 - val_accuracy: 0.6725
# Epoch 82/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0072 - accuracy: 0.9973 - val_loss: 2.5857 - val_accuracy: 0.6786
# Epoch 83/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0085 - accuracy: 0.9974 - val_loss: 3.5363 - val_accuracy: 0.6602
# Epoch 84/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 5.7500 - val_accuracy: 0.6128
# Epoch 85/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0100 - accuracy: 0.9969 - val_loss: 3.8816 - val_accuracy: 0.6634
# Epoch 86/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0140 - accuracy: 0.9953 - val_loss: 3.1945 - val_accuracy: 0.6660
# Epoch 87/100
# 568/568 [==============================] - 8s 13ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 4.0730 - val_accuracy: 0.6570
# Epoch 88/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0114 - accuracy: 0.9969 - val_loss: 4.7352 - val_accuracy: 0.6366
# Epoch 89/100
# 568/568 [==============================] - 8s 14ms/step - loss: 0.0095 - accuracy: 0.9969 - val_loss: 3.0685 - val_accuracy: 0.6599
# Epoch 90/100
# 568/568 [==============================] - 6s 11ms/step - loss: 0.0066 - accuracy: 0.9982 - val_loss: 2.7052 - val_accuracy: 0.6739
# Epoch 91/100
# 568/568 [==============================] - 8s 13ms/step - loss: 0.0095 - accuracy: 0.9974 - val_loss: 2.7378 - val_accuracy: 0.6584
# Epoch 92/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0105 - accuracy: 0.9969 - val_loss: 3.9015 - val_accuracy: 0.6618
# Epoch 93/100
# 568/568 [==============================] - 8s 14ms/step - loss: 0.0067 - accuracy: 0.9980 - val_loss: 6.2342 - val_accuracy: 0.6418
# Epoch 94/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0101 - accuracy: 0.9971 - val_loss: 2.6899 - val_accuracy: 0.6736
# Epoch 95/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 5.1573 - val_accuracy: 0.6532
# Epoch 96/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0082 - accuracy: 0.9974 - val_loss: 4.2432 - val_accuracy: 0.6605
# Epoch 97/100
# 568/568 [==============================] - 7s 13ms/step - loss: 0.0085 - accuracy: 0.9974 - val_loss: 3.7998 - val_accuracy: 0.6389
# Epoch 98/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0083 - accuracy: 0.9977 - val_loss: 3.7775 - val_accuracy: 0.6430
# Epoch 99/100
# 568/568 [==============================] - 8s 13ms/step - loss: 0.0113 - accuracy: 0.9967 - val_loss: 3.9488 - val_accuracy: 0.6521
# Epoch 100/100
# 568/568 [==============================] - 7s 12ms/step - loss: 0.0109 - accuracy: 0.9970 - val_loss: 5.0717 - val_accuracy: 0.6128

# %%
import itertools
his_Tacc = sum(his_Tacc, [])
his_Vacc = sum(his_Vacc, [])
his_Tloss = sum(his_Tloss, [])
his_Vloss = sum(his_Vloss, [])

# %%
plt.plot(his_Tacc[:], label='Training Accuracy')
plt.plot(his_Vacc[:], label='Validation Accuracy')
plt.title('Training and Validation Accuracy Curves')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_features, test_labels)
print('Test accuracy:', test_acc)
# Out:
# 420/420 [==============================] - 3s 6ms/step - loss: 1.2209 - accuracy: 0.6292
# Test accuracy: 0.6292461156845093

# %%
import matplotlib.pyplot as plt
plt.plot(his_Tloss[:64], label='Training Loss')
plt.plot(his_Vloss[:64], label='Validation Loss')
plt.title('Training and Validation Loss Curves')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(his_Vacc[0], label='fold1')
plt.plot(his_Vacc[1], label='fold2')
plt.plot(his_Vacc[2], label='fold3')
plt.plot(his_Vacc[3], label='fold4')
plt.plot(his_Vacc[4], label='fold5')
plt.title('Validation Accuracy Curves')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(his_Vloss[0], label='fold1')
plt.plot(his_Vloss[1], label='fold2')
plt.plot(his_Vloss[2], label='fold3')
plt.plot(his_Vloss[3], label='fold4')
plt.plot(his_Vacc[4], label='fold5')
plt.title('Validation Loss Curves')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(val_accs, label='Validation Acc')
plt.title('Validation Accuracy after each fold')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Saving the model for Future Inferences

model_json = model.to_json()
with open("model2.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model4.h5")

# %% [markdown]
# # **V4**

# %%
from keras import regularizers
model = Sequential()
model.add(InputLayer(input_shape=(200, 21)))

model.add(Conv1D(32, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())

model.add(Conv1D(64, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())

model.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.6))

model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.6))

model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
