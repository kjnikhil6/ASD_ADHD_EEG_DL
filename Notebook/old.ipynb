# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %%capture
# !pip install mne

# %% [markdown]
# # **The DATASET**

# %%
from glob import glob
import os
import mne
import numpy as np
import pandas
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
import re

# %%
ASD_file_path = glob('/content/gdrive/My Drive/MAIN PROJECT/ICCONS/ASD/*.fif')
ADHD_file_path = glob('/content/gdrive/My Drive/MAIN PROJECT/ICCONS/ADHD/*.fif')
test_ASD_file_path = glob('/content/gdrive/My Drive/MAIN PROJECT/ICCONS/test_ASD/*.fif')
test_ADHD_file_path = glob('/content/gdrive/My Drive/MAIN PROJECT/ICCONS/test_ADHD/*.fif')
print(len(ASD_file_path), len(ADHD_file_path))
print(len(test_ASD_file_path), len(test_ADHD_file_path))
# Out:
# 30 26
# 3 3

# %%
def subj_id_finder(file_path):
  pattern = r'(\w+)/(\d+)_(\d+)\.fif'
  match = re.search(pattern, file_path)
  disorder = match.group(1)
  subj_id=int(match.group(2))
  if disorder == 'ADHD':
    subj_id+=16
  return subj_id

# %%
# raw = mne.io.read_raw_fif(ASD_file_path[0], preload=True)
# raw

# %%
from scipy.signal import hann
import matplotlib.pyplot as plt
def sliding_window(file_path, l_freq=1.0, h_freq=30.0, decim_factor=1,test=False):

    subj_id = subj_id_finder(file_path)
    raw = mne.io.read_raw_fif(file_path, preload=True)
    raw.filter(l_freq=0.3,h_freq=30)

    data = raw.get_data()

    window_size = 1 * int(raw.info['sfreq'])#250samples
    stride = window_size// 2

    windows = []
    for i in range(0, data.shape[1] - window_size + 1, stride):
        window_data = data[:, i:i+window_size]
        # Apply a low-pass anti-aliasing filter to avoid aliasing
        #anti_alias_data = mne.filter.filter_data(window_data, sfreq=raw.info['sfreq'],  l_freq= 40 , h_freq=None,)
        hann_window = hann(window_size, sym=False)
        window_data = window_data*hann_window
        # Decimate the signal
        decimated_data = mne.filter.resample(window_data, down=1.25, npad='auto')
        windows.append(decimated_data)
        if not test:
          group_list.append(subj_id)


    arr = np.array(windows)
    if len(arr)!=0:
      return arr

# %%
# sample_data = sliding_window(ASD_file_path[11])
# sample_data.shape

# %%
# %%capture
group_list=[]
ASD_epochs_arr = [sliding_window(i) for i in ASD_file_path ]
ADHD_epochs_arr = [sliding_window(i) for i in ADHD_file_path]
test_ASD_epochs_arr = [sliding_window(i,test=True) for i in test_ASD_file_path]
test_ADHD_epochs_arr = [sliding_window(i,test=True) for i in test_ADHD_file_path]

# %%
ASD_epochs_arr[1].shape,len(ASD_epochs_arr)
# Out:
# ((3195, 21, 200), 30)

# %%
ASD_epochs_labels = [len(i)*[0] for i in ASD_epochs_arr.copy()]
ADHD_epochs_labels = [len(i)*[1] for i in ADHD_epochs_arr.copy()]
test_ASD_epochs_labels = [len(i)*[0] for i in test_ASD_epochs_arr.copy()]
test_ADHD_epochs_labels = [len(i)*[1] for i in test_ADHD_epochs_arr.copy()]
len(ASD_epochs_labels),len(ADHD_epochs_labels)
# Out:
# (30, 26)

# %%
data_list = ASD_epochs_arr.copy()+ADHD_epochs_arr.copy()
ADHD_epochs_arr=0
ASD_epochs_arr=0
label_list = ASD_epochs_labels+ADHD_epochs_labels
#         [-9.40910439e-03,  4.11566899e-03, -2.56165075e-02, ...,
#          -3.40003954e-02, -3.91551342e-02,  1.00307325e-02],
#         ...,
#         [-1.08709889e-02,  1.13865723e-03, -4.71938780e-02, ...,
#          -3.93579586e-02, -4.46460466e-02,  1.22336242e-02],
#         [-2.08224269e-02,  1.55928741e-02, -4.68580087e-02, ...,
#           3.06899475e-02, -4.46514383e-02,  3.88355412e-02],
#         [-1.16771707e-02,  4.76852067e-03, -3.91912244e-02, ...,
#           4.41669909e-02, -1.40406209e-02,  2.27318686e-02]],
#
#        [[ 3.75905042e-04,  3.91973398e-04,  1.74779289e-03, ...,
#           4.85370136e-02,  1.81530550e-02,  4.87131829e-03],
#         [ 5.44676185e-03, -1.32605733e-03,  1.82777171e-02, ...,
#           5.99759372e-02,  3.87567713e-02, -8.66422948e-04],
#         [ 4.56938434e-03, -4.75320815e-03, -1.42375302e-03, ...,
#          -2.57981045e-02, -1.08923773e-03, -1.08454133e-02],
#         ...,
#         [ 1.29509904e-02, -1.39700639e-02,  6.01508636e-03, ...,
#          -1.72767736e-02,  2.67218128e-02, -2.19645061e-02],
#         [ 1.79241399e-02, -1.19518458e-02,  3.67438029e-02, ...,
#           6.42476717e-02,  8.44477813e-02, -1.72358154e-02],
#         [-4.67130735e-04,  1.19737726e-02,  4.02211808e-02, ...,
#          -4.71878150e-02, -1.77076093e-02, -5.04987236e-03]],
#
#        [[ 1.11387754e-03,  3.13207644e-04,  9.14391160e-03, ...,
#          -1.05208364e-03,  8.14064745e-03, -4.47698442e-03],
#         [ 2.51293495e-03,  3.00235140e-03,  2.65054742e-02, ...,
#           3.11646900e-04,  6.90367619e-03, -6.17866196e-03],
#         [ 4.68991798e-03, -1.01118037e-02, -1.24074787e-02, ...,
#          -1.62477094e-02,  5.92942101e-03, -9.88825977e-03],
#         ...,
#         [ 8.62374768e-03, -1.37376912e-02, -5.14980658e-03, ...,
#          -2.14861252e-02,  1.18376613e-02, -1.65948886e-02],
#         [ 3.46249146e-03, -2.32683074e-03,  1.36085105e-02, ...,
#           5.51745212e-03,  1.25375711e-02, -5.22946339e-03],
#         [-3.30742478e-03,  4.32501658e-03,  2.04177502e-03, ...,
#           4.88772915e-03, -4.09669840e-03,  6.95703902e-03]]])

# %%
print(len(data_list))
len(group_list),len(label_list)
# Out:
# 56
# (72676, 56)

# %%
train_features = np.vstack(data_list)
data_list=0
test_features = np.vstack(test_data_list)
test_data_list=0
label_arr = np.hstack(label_list)
label_list=0
test_labels = np.hstack(test_label_list)
test_label_list=0
group_arr =np.hstack(group_list)
#group_list=0

# %%
group_arr.shape,train_features.shape,label_arr.shape
# Out:
# ((72676,), (72676, 21, 200), (72676,))

# %%
group_arr
# Out:
# array([ 1,  1,  1, ..., 31, 31, 31])

# %%
test_features = np.moveaxis(test_features,1,2)
test_features.shape
train_features = np.moveaxis(train_features,1,2)
train_features.shape
# Out:
# (72676, 200, 21)

# %%
data_list=0
test_data_list=0
label_list=0
test_label_list=0

# %%
label_arr
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
train_labels = label_arr.copy()

# %%
train_labels.shape
# Out:
# (72676,)

# %%
# from sklearn.preprocessing import StandardScaler
# scaler =  StandardScaler()
# test_features=scaler.fit_transform(test_data.reshape(-1,\
#                     test_data.shape[-1])).reshape(test_data.shape)

# %% [markdown]
# ## **Train-Test split**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GroupKFold, LeaveOneGroupOut
scaler =  StandardScaler()
gkf=GroupKFold(n_splits=10)

# %%
train_index, val_index = gkf.split(data_arr, label_arr, groups=group_arr)
val_index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-309e66190c6c> in <cell line: 1>()
# ----> 1 train_index, val_index = gkf.split(data_arr, label_arr, groups=group_arr)
#       2 val_index
#
# NameError: name 'data_arr' is not defined

# %%
train_data, val_data, train_labels, val_labels = train_test_split(data_arr, label_arr, test_size=0.2,
                                                                        random_state=42, stratify=label_arr)

# %%
# Use GroupKFold to split the data into training and validation sets
co=0
for train_index, val_index in gkf.split(train_features, train_labels, groups=group_arr):
    # Use the train_index and val_index to create the training and validation sets
    #train_data = train_features[train_index]
    #train_label =train_labels[train_index]
    #val_data = train_features[val_index]
    #val_label = train_labels[val_index]
    history = model.fit(train_features[train_index],train_labels[train_index],
                    epochs=75,batch_size=32,
                    callbacks=[early_stopping],
                    shuffle=True,
                    validation_data=(train_features[val_index],train_labels[val_index]))

    break
# Out:
# Epoch 1/75
# 2062/2062 [==============================] - 17s 8ms/step - loss: 0.3583 - accuracy: 0.8478 - val_loss: 1.3815 - val_accuracy: 0.2665
# Epoch 2/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.3391 - accuracy: 0.8562 - val_loss: 0.9059 - val_accuracy: 0.4928
# Epoch 3/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.3230 - accuracy: 0.8648 - val_loss: 0.9279 - val_accuracy: 0.4876
# Epoch 4/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.3149 - accuracy: 0.8696 - val_loss: 1.3330 - val_accuracy: 0.3299
# Epoch 5/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.3052 - accuracy: 0.8746 - val_loss: 1.0199 - val_accuracy: 0.5074
# Epoch 6/75
# 2062/2062 [==============================] - 17s 8ms/step - loss: 0.2966 - accuracy: 0.8790 - val_loss: 1.3649 - val_accuracy: 0.3604
# Epoch 7/75
# 2062/2062 [==============================] - 15s 7ms/step - loss: 0.2919 - accuracy: 0.8798 - val_loss: 0.9350 - val_accuracy: 0.4867
# Epoch 8/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.2852 - accuracy: 0.8841 - val_loss: 1.1872 - val_accuracy: 0.3620
# Epoch 9/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.2799 - accuracy: 0.8863 - val_loss: 0.8194 - val_accuracy: 0.6076
# Epoch 10/75
# 2062/2062 [==============================] - 15s 7ms/step - loss: 0.2745 - accuracy: 0.8888 - val_loss: 1.6307 - val_accuracy: 0.2931
# Epoch 11/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.2657 - accuracy: 0.8931 - val_loss: 1.6006 - val_accuracy: 0.3117
# Epoch 12/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.2554 - accuracy: 0.8974 - val_loss: 0.9687 - val_accuracy: 0.5922
# Epoch 13/75
# 2062/2062 [==============================] - 15s 8ms/step - loss: 0.2488 - accuracy: 0.9024 - val_loss: 0.5768 - val_accuracy: 0.7361
# Epoch 14/75
# 2062/2062 [==============================] - 15s 7ms/step - loss: 0.2468 - accuracy: 0.9031 - val_loss: 1.8530 - val_accuracy: 0.3714
# Epoch 15/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.2384 - accuracy: 0.9079 - val_loss: 0.9819 - val_accuracy: 0.6056
# Epoch 16/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.2349 - accuracy: 0.9095 - val_loss: 1.3413 - val_accuracy: 0.4647
# Epoch 17/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.2299 - accuracy: 0.9108 - val_loss: 1.2202 - val_accuracy: 0.4923
# Epoch 18/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.2236 - accuracy: 0.9137 - val_loss: 1.0068 - val_accuracy: 0.5897
# Epoch 19/75
# 2062/2062 [==============================] - 15s 7ms/step - loss: 0.2201 - accuracy: 0.9152 - val_loss: 1.3682 - val_accuracy: 0.5085
# Epoch 20/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.2173 - accuracy: 0.9176 - val_loss: 1.4379 - val_accuracy: 0.4639
# Epoch 21/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.2139 - accuracy: 0.9170 - val_loss: 1.1346 - val_accuracy: 0.5511
# Epoch 22/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.2103 - accuracy: 0.9202 - val_loss: 1.0127 - val_accuracy: 0.5253
# Epoch 23/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.2094 - accuracy: 0.9209 - val_loss: 1.7726 - val_accuracy: 0.3939
# Epoch 24/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.2095 - accuracy: 0.9215 - val_loss: 1.6616 - val_accuracy: 0.4027
# Epoch 25/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.2054 - accuracy: 0.9222 - val_loss: 0.7339 - val_accuracy: 0.7089
# Epoch 26/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.2058 - accuracy: 0.9223 - val_loss: 1.4207 - val_accuracy: 0.4702
# Epoch 27/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.2009 - accuracy: 0.9248 - val_loss: 0.8393 - val_accuracy: 0.6503
# Epoch 28/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.2009 - accuracy: 0.9247 - val_loss: 0.8508 - val_accuracy: 0.6465
# Epoch 29/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.2000 - accuracy: 0.9245 - val_loss: 1.5033 - val_accuracy: 0.3841
# Epoch 30/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.1972 - accuracy: 0.9276 - val_loss: 1.1894 - val_accuracy: 0.4999
# Epoch 31/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.1943 - accuracy: 0.9270 - val_loss: 0.7569 - val_accuracy: 0.6709
# Epoch 32/75
# 2062/2062 [==============================] - 17s 8ms/step - loss: 0.1935 - accuracy: 0.9290 - val_loss: 1.3485 - val_accuracy: 0.4711
# Epoch 33/75
# 2062/2062 [==============================] - 16s 8ms/step - loss: 0.1932 - accuracy: 0.9268 - val_loss: 0.7232 - val_accuracy: 0.6654

# %%
history = model.fit(train_features[train_index],train_labels[train_index],
                    epochs=50,batch_size=32,
                    callbacks=[early_stopping],
                    shuffle=True,
                    validation_data=(train_features[val_index],train_labels[val_index]))

# %%
train_data = data_arr[train_index[0]]
train_labels = label_arr[train_index[0]]
val_data = data_arr[val_index[0]]
val_labels = label_arr[val_index[0]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-d06aed1ce755> in <cell line: 1>()
# ----> 1 train_data = data_arr[train_index[0]]
#       2 train_labels = label_arr[train_index[0]]
#       3 val_data = data_arr[val_index[0]]
#       4 val_labels = label_arr[val_index[0]]
#
# NameError: name 'train_index' is not defined

# %%
train_data = np.moveaxis(train_data,1,2)
val_data  = np.moveaxis(val_data,1,2)

# %%
val_data.shape
# Out:
# (3598, 1000, 21)

# %%
val_labels
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
train_features=scaler.fit_transform(train_features.reshape(-1,\
                    train_features.shape[-1])).reshape(train_features.shape)
#val_features=scaler.transform(val_data.reshape(-1,\
#                   val_data.shape[-1])).reshape(val_data.shape)
test_features=scaler.fit_transform(test_features.reshape(-1,\
                    test_features.shape[-1])).reshape(test_features.shape)

# %%
train_data=[]
test_data=[]

# %% [markdown]
# # **CNN Model_1**

# %%
from tensorflow.keras.layers import Conv1D,BatchNormalization,LeakyReLU,MaxPool1D,\
GlobalAveragePooling1D,Dense,Dropout,AveragePooling1D,ReLU,MaxPooling1D,InputLayer,Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.backend import clear_session
from tensorflow.keras.utils import plot_model
import keras.backend as K
K.clear_session()

# %%
def cnnmodel1():
  clear_session()
  model=Sequential()
  model.add(Conv1D(filters=5,kernel_size=3,strides=1,input_shape=(200,21)))#1
  model.add(BatchNormalization())
  model.add(LeakyReLU())
  model.add(MaxPool1D(pool_size=2,strides=2))#2
  model.add(Conv1D(filters=5,kernel_size=3,strides=1))#3
  model.add(LeakyReLU())
  model.add(MaxPool1D(pool_size=2,strides=2))#4
  model.add(Dropout(0.5))
  model.add(Conv1D(filters=5,kernel_size=3,strides=1))#5
  model.add(LeakyReLU())
  model.add(AveragePooling1D(pool_size=2,strides=2))#6
  model.add(Dropout(0.5))
  model.add(Conv1D(filters=5,kernel_size=3,strides=1))#7
  model.add(LeakyReLU())
  model.add(AveragePooling1D(pool_size=2,strides=2))#8
  model.add(Conv1D(filters=5,kernel_size=3,strides=1))#9
  model.add(LeakyReLU())
  model.add(GlobalAveragePooling1D())#10
  model.add(Dense(1,activation='sigmoid'))#11

  model.compile('adam',loss='binary_crossentropy',metrics=['accuracy'])
  return model
def cnnmodel2():
  clear_session()
  model=Sequential()
  model.add(Conv1D(filters=10,kernel_size=5,strides=1,input_shape=(200,21)))#1
  model.add(BatchNormalization())
  model.add(LeakyReLU())
  model.add(MaxPool1D(pool_size=2,strides=2))#2
  model.add(Conv1D(filters=20,kernel_size=3,strides=1))#3
  model.add(LeakyReLU())
  model.add(MaxPool1D(pool_size=2,strides=2))#4
  model.add(Dropout(0.5))
  model.add(Conv1D(filters=30,kernel_size=3,strides=1))#5
  model.add(LeakyReLU())
  model.add(AveragePooling1D(pool_size=2,strides=2))#6
  model.add(Dropout(0.5))
  model.add(Conv1D(filters=40,kernel_size=3,strides=1))#7
  model.add(ReLU())
  model.add(AveragePooling1D(pool_size=2,strides=2))#8
  model.add(Conv1D(filters=50,kernel_size=3,strides=1))#9
  model.add(ReLU())
  model.add(GlobalAveragePooling1D())#10
  model.add(Dense(64,activation='relu'))#11
  model.add(Dropout(0.5))
  model.add(Dense(1,activation='sigmoid'))#12

  model.compile('adam',loss='binary_crossentropy',metrics=['accuracy'])
  return model
model=cnnmodel2()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 196, 10)           1060
#
#  batch_normalization (BatchN  (None, 196, 10)          40
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 196, 10)           0
#
#  max_pooling1d (MaxPooling1D  (None, 98, 10)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 96, 20)            620
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 96, 20)            0
#
#  max_pooling1d_1 (MaxPooling  (None, 48, 20)           0
#  1D)
#
#  dropout (Dropout)           (None, 48, 20)            0
#
#  conv1d_2 (Conv1D)           (None, 46, 30)            1830
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 46, 30)            0
#
#  average_pooling1d (AverageP  (None, 23, 30)           0
#  ooling1D)
#
#  dropout_1 (Dropout)         (None, 23, 30)            0
#
#  conv1d_3 (Conv1D)           (None, 21, 40)            3640
#
#  re_lu (ReLU)                (None, 21, 40)            0
#
#  average_pooling1d_1 (Averag  (None, 10, 40)           0
#  ePooling1D)
#
#  conv1d_4 (Conv1D)           (None, 8, 50)             6050
#
#  re_lu_1 (ReLU)              (None, 8, 50)             0
#
#  global_average_pooling1d (G  (None, 50)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 64)                3264
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 16,569
# Trainable params: 16,549
# Non-trainable params: 20
# _________________________________________________________________

# %%
history = model.fit(train_features,train_labels,epochs=100,batch_size=32,shuffle=True,validation_data=(test_features,test_labels))
# Out:
# Epoch 1/100
# 2268/2268 [==============================] - 34s 14ms/step - loss: 0.6122 - accuracy: 0.8159 - val_loss: 0.9677 - val_accuracy: 0.5358
# Epoch 2/100
# 2268/2268 [==============================] - 20s 9ms/step - loss: 0.2879 - accuracy: 0.8858 - val_loss: 0.9317 - val_accuracy: 0.5638
# Epoch 3/100
# 2268/2268 [==============================] - 22s 10ms/step - loss: 0.2470 - accuracy: 0.9031 - val_loss: 0.9531 - val_accuracy: 0.5656
# Epoch 4/100
# 2268/2268 [==============================] - 20s 9ms/step - loss: 0.2199 - accuracy: 0.9151 - val_loss: 0.9331 - val_accuracy: 0.5815
# Epoch 5/100
# 2268/2268 [==============================] - 21s 9ms/step - loss: 0.2055 - accuracy: 0.9222 - val_loss: 0.8820 - val_accuracy: 0.6119
# Epoch 6/100
# 2268/2268 [==============================] - 22s 10ms/step - loss: 0.1904 - accuracy: 0.9293 - val_loss: 0.8325 - val_accuracy: 0.6093
# Epoch 7/100
# 2268/2268 [==============================] - 21s 9ms/step - loss: 0.1770 - accuracy: 0.9341 - val_loss: 1.0601 - val_accuracy: 0.6107
# Epoch 8/100
# 2268/2268 [==============================] - 21s 9ms/step - loss: 0.1691 - accuracy: 0.9390 - val_loss: 0.7673 - val_accuracy: 0.6406
# Epoch 9/100
# 2268/2268 [==============================] - 21s 9ms/step - loss: 0.1593 - accuracy: 0.9421 - val_loss: 0.7382 - val_accuracy: 0.6818
# Epoch 10/100
# 2268/2268 [==============================] - 21s 9ms/step - loss: 0.1549 - accuracy: 0.9443 - val_loss: 0.7910 - val_accuracy: 0.6478
# Epoch 11/100
# 2268/2268 [==============================] - 20s 9ms/step - loss: 0.1488 - accuracy: 0.9468 - val_loss: 0.8463 - val_accuracy: 0.6543
# Epoch 12/100
# 2268/2268 [==============================] - 22s 10ms/step - loss: 0.1427 - accuracy: 0.9497 - val_loss: 0.8654 - val_accuracy: 0.6288
# Epoch 13/100
# 2268/2268 [==============================] - 21s 9ms/step - loss: 0.1405 - accuracy: 0.9509 - val_loss: 0.8792 - val_accuracy: 0.6487
# Epoch 14/100
# 2268/2268 [==============================] - 21s 9ms/step - loss: 0.1338 - accuracy: 0.9536 - val_loss: 0.8786 - val_accuracy: 0.6618
# Epoch 15/100
# 2268/2268 [==============================] - 21s 9ms/step - loss: 0.1324 - accuracy: 0.9541 - val_loss: 0.8843 - val_accuracy: 0.6569
# Epoch 16/100
# 2268/2268 [==============================] - 21s 9ms/step - loss: 0.1297 - accuracy: 0.9568 - val_loss: 0.7335 - val_accuracy: 0.6755
# Epoch 17/100
# 2268/2268 [==============================] - 21s 9ms/step - loss: 0.1265 - accuracy: 0.9572 - val_loss: 0.7440 - val_accuracy: 0.6801
# Epoch 18/100
# 2268/2268 [==============================] - 22s 10ms/step - loss: 0.1258 - accuracy: 0.9575 - val_loss: 0.9491 - val_accuracy: 0.6665
# Epoch 19/100
# 2268/2268 [==============================] - 21s 9ms/step - loss: 0.1200 - accuracy: 0.9599 - val_loss: 0.8681 - val_accuracy: 0.6622
# Epoch 20/100
# 2268/2268 [==============================] - 22s 10ms/step - loss: 0.1181 - accuracy: 0.9608 - val_loss: 0.7833 - val_accuracy: 0.6736
# Epoch 21/100
# 2268/2268 [==============================] - 21s 9ms/step - loss: 0.1180 - accuracy: 0.9605 - val_loss: 0.7355 - val_accuracy: 0.6975
# Epoch 22/100
# 2268/2268 [==============================] - 23s 10ms/step - loss: 0.1146 - accuracy: 0.9614 - val_loss: 0.7836 - val_accuracy: 0.6933
# Epoch 23/100
# 2268/2268 [==============================] - 22s 10ms/step - loss: 0.1126 - accuracy: 0.9631 - val_loss: 0.8535 - val_accuracy: 0.6858
# Epoch 24/100
# 2268/2268 [==============================] - 24s 10ms/step - loss: 0.1127 - accuracy: 0.9639 - val_loss: 0.9673 - val_accuracy: 0.6330
# Epoch 25/100
# 2268/2268 [==============================] - 21s 9ms/step - loss: 0.1106 - accuracy: 0.9641 - val_loss: 0.8237 - val_accuracy: 0.6885
# Epoch 26/100
# 2268/2268 [==============================] - 22s 10ms/step - loss: 0
# 2268/2268 [==============================] - 25s 11ms/step - loss: 0.0646 - accuracy: 0.9816 - val_loss: 0.7625 - val_accuracy: 0.7362
# Epoch 99/100
# 2268/2268 [==============================] - 26s 12ms/step - loss: 0.0677 - accuracy: 0.9803 - val_loss: 1.0800 - val_accuracy: 0.6752
# Epoch 100/100
# 2268/2268 [==============================] - 26s 11ms/step - loss: 0.0646 - accuracy: 0.9816 - val_loss: 0.8631 - val_accuracy: 0.7180

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Curves')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy Curves')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # **ChroNet**

# %%
from tensorflow.keras.layers import Input,Dense,concatenate,Flatten,GRU,Conv1D
from tensorflow.keras.models import Model

# %%
def block(input):
  conv1 = Conv1D(filters=32,kernel_size=2,strides=2,activation='relu',padding='causal')(input)
  conv2 = Conv1D(filters=32,kernel_size=4,strides=2,activation='relu',padding='causal')(input)
  conv3 = Conv1D(filters=32,kernel_size=8,strides=2,activation='relu',padding='causal')(input)
  x = concatenate([conv1,conv2,conv3],axis=2)
  return x

# %%
input = Input(shape=(200, 21))
block1 = block(input)
block1.shape
# Out:
# TensorShape([None, 100, 96])

# %%
block2 = block(block1)
block3 = block(block2)
block3.shape
# Out:
# TensorShape([None, 25, 96])

# %%
gru1 = GRU(units=32,return_sequences=True)(block3)
gru2 = GRU(units=32,return_sequences=True)(gru1)
gru_out = concatenate([gru1,gru2],axis=2)

gru3 = GRU(units=32,return_sequences=True)(gru_out)
gru_out = concatenate([gru1,gru2,gru3],axis=2)
gru_out.shape
# Out:
# TensorShape([None, 25, 96])

# %%
gru4 = GRU(units=32)(gru_out)
out2 = Dense(16,activation='relu')(gru4)
out = Dense(1,activation='sigmoid')(out2)

# %%
model = Model(inputs=input,outputs=out)
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
val_accs = []
his_Tacc=[]
his_Vacc=[]
his_Tloss=[]
his_Vloss=[]
for train_index, val_index in gkf.split(train_features, train_labels, groups=group_arr):
    # Use the train_index and val_index to create the training and validation sets
    train_data = train_features[train_index]

    train_label = train_labels[train_index]
    test_data = train_features[val_index]
    test_label = train_labels[val_index]

    history = model.fit(train_data,train_label,epochs=10,batch_size=32,validation_data=(test_data,test_label))

    his_Tloss.append(history.history['loss'])
    his_Vloss.append(history.history['val_loss'])
    his_Tacc.append(history.history['accuracy'])
    his_Vacc.append(history.history['val_accuracy'])


    val_accs.append(history.history['val_accuracy'][-1])

print('Average validation accuracy:', sum(val_accs) / len(val_accs))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-30b5e398b0e8> in <cell line: 6>()
#       4 his_Tloss=[]
#       5 his_Vloss=[]
# ----> 6 for train_index, val_index in gkf.split(train_features, train_labels, groups=group_arr):
#       7     # Use the train_index and val_index to create the training and validation sets
#       8     train_data = train_features[train_index]
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#     340             The testing set indices for that split.
#     341         """
# --> 342         X, y, groups = indexable(X, y, groups)
#     343         n_samples = _num_samples(X)
#     344         if self.n_splits > n_samples:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     441
#     442     result = [_make_indexable(X) for X in iterables]
# --> 443     check_consistent_length(*result)
#     444     return result
#     445
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
# --> 397         raise ValueError(
#     398             "Found input variables with inconsistent numbers of samples: %r"
#     399             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [3185, 3185, 5081]

# %% [markdown]
# # **v3**

# %%
model = Sequential()
model.add(InputLayer(input_shape=(200, 21)))
model.add(Conv1D(64, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())
model.add(Conv1D(64, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())
model.add(Conv1D(128, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())
model.add(Conv1D(128, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())
model.add(Conv1D(256, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.compile('adam',loss='binary_crossentropy',metrics=['accuracy'])
#history = model.fit(train_features,train_labels,epochs=50,batch_size=32,validation_data=(test_features,test_labels))

# %%
plot_model(model, to_file="my_model.png", show_shapes=True)

# %%
val_accs = []
his_Tacc=[]
his_Vacc=[]
his_Tloss=[]
his_Vloss=[]
for train_index, val_index in gkf.split(train_features, train_labels, groups=group_arr):
    # Use the train_index and val_index to create the training and validation sets
    train_data = train_features[train_index]

    train_label = train_labels[train_index]
    #test_data = train_features[val_index]
    #test_label = train_labels[val_index]

    history = model.fit(train_data,train_label,epochs=100,batch_size=128,validation_data=(test_features,test_labels))

    his_Tloss.append(history.history['loss'])
    his_Vloss.append(history.history['val_loss'])
    his_Tacc.append(history.history['accuracy'])
    his_Vacc.append(history.history['val_accuracy'])


    val_accs.append(history.history['val_accuracy'][-1])

print('Average validation accuracy:', sum(val_accs) / len(val_accs))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-925fda8d3532> in <cell line: 6>()
#       4 his_Tloss=[]
#       5 his_Vloss=[]
# ----> 6 for train_index, val_index in gkf.split(train_features, train_labels, groups=group_arr):
#       7     # Use the train_index and val_index to create the training and validation sets
#       8     train_data = train_features[train_index]
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#     340             The testing set indices for that split.
#     341         """
# --> 342         X, y, groups = indexable(X, y, groups)
#     343         n_samples = _num_samples(X)
#     344         if self.n_splits > n_samples:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     441
#     442     result = [_make_indexable(X) for X in iterables]
# --> 443     check_consistent_length(*result)
#     444     return result
#     445
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
# --> 397         raise ValueError(
#     398             "Found input variables with inconsistent numbers of samples: %r"
#     399             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [72564, 72564, 115710]

# %%
history = model.fit(train_features,train_labels,epochs=100,batch_size=32,validation_data=(test_features,test_labels))

# %%
import itertools
his_Tacc = sum(his_Tacc, [])
his_Vacc = sum(his_Vacc, [])
his_Tloss = sum(his_Tloss, [])
his_Vloss = sum(his_Vloss, [])

# %%
plt.plot(his_Tacc[:], label='Training Accuracy')
plt.plot(his_Vacc[:], label='Validation Accuracy')
plt.title('Training and Validation Accuracy Curves')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_features, test_labels)
print('Test accuracy:', test_acc)
# Out:
# 420/420 [==============================] - 3s 6ms/step - loss: 0.8869 - accuracy: 0.7305
# Test accuracy: 0.7304826974868774

# %%
import matplotlib.pyplot as plt
plt.plot(his_Tloss[:64], label='Training Loss')
plt.plot(his_Vloss[:64], label='Validation Loss')
plt.title('Training and Validation Loss Curves')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(his_Vacc[0], label='fold1')
plt.plot(his_Vacc[1], label='fold2')
plt.plot(his_Vacc[2], label='fold3')
plt.plot(his_Vacc[3], label='fold4')
plt.plot(his_Vacc[4], label='fold5')
plt.title('Validation Accuracy Curves')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(his_Vloss[0], label='fold1')
plt.plot(his_Vloss[1], label='fold2')
plt.plot(his_Vloss[2], label='fold3')
plt.plot(his_Vloss[3], label='fold4')
plt.plot(his_Vacc[4], label='fold5')
plt.title('Validation Loss Curves')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(val_accs, label='Validation Acc')
plt.title('Validation Accuracy after each fold')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Saving the model for Future Inferences

model_json = model.to_json()
with open("model_73v4.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model_73v4.h5")

# %% [markdown]
# # **V4**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GroupKFold, LeaveOneGroupOut
scaler =  StandardScaler()
gkf=GroupKFold(n_splits=5)
train_features=scaler.fit_transform(train_features.reshape(-1,\
                    train_features.shape[-1])).reshape(train_features.shape)
#val_features=scaler.transform(val_data.reshape(-1,\
#                   val_data.shape[-1])).reshape(val_data.shape)
test_features=scaler.fit_transform(test_features.reshape(-1,\
                    test_features.shape[-1])).reshape(test_features.shape)

# %%
from tensorflow.keras.layers import Conv1D,BatchNormalization,LeakyReLU,MaxPool1D,\
GlobalAveragePooling1D,Dense,Dropout,AveragePooling1D,ReLU,MaxPooling1D,InputLayer,Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.backend import clear_session
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
import keras.backend as K
K.clear_session()

# %%
from keras import regularizers
model = Sequential()
model.add(InputLayer(input_shape=(200, 21)))

model.add(Conv1D(32, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())

model.add(Conv1D(64, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())

model.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.6))

model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.6))

model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
from keras import regularizers
model = Sequential()
model.add(InputLayer(input_shape=(200, 21)))

model.add(Conv1D(32, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())

model.add(Conv1D(64, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())

model.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.6))
model.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model.add(Dropout(0.05))
model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model.add(Dropout(0.6))

model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))
opt1=Adam(learning_rate=0.001)
model.compile(optimizer=opt1, loss='binary_crossentropy', metrics=['accuracy'])

# %%
model=0

# %%
epochs=60
learning_rate=0.001
decay_rate = learning_rate / epochs
def exp_decay(epoch):
  lr = lr*tensorflow.math.exp(-decay_rate*epoch)
  return lrate

lr_rate = LearningRateScheduler(exp_decay)
callbacks_list = [lr_rate]

# %%
# from tensorflow.keras.callbacks import LearningRateScheduler
# from tensorflow import math
# def schedular(epoch,lr):
#   if epoch<=20:
#     return lr*math.exp(-0.1)
#   else:
#     lr = lr*0.008
#     return lr
# callback = LearningRateScheduler(schedular)

# %%
history = model.fit(train_features,train_labels,
                    epochs=70,batch_size=32,
                    callbacks=[early_stopping],
                    shuffle=True,
                    validation_data=(test_features,test_labels))
# Out:
# Epoch 1/70
# 2272/2272 [==============================] - 45s 13ms/step - loss: 0.5036 - accuracy: 0.7560 - val_loss: 0.8487 - val_accuracy: 0.5433
# Epoch 2/70
# 2272/2272 [==============================] - 27s 12ms/step - loss: 0.3861 - accuracy: 0.8295 - val_loss: 0.7474 - val_accuracy: 0.5604
# Epoch 3/70
# 2272/2272 [==============================] - 27s 12ms/step - loss: 0.3320 - accuracy: 0.8582 - val_loss: 0.8675 - val_accuracy: 0.5786
# Epoch 4/70
# 2272/2272 [==============================] - 27s 12ms/step - loss: 0.3007 - accuracy: 0.8750 - val_loss: 0.7969 - val_accuracy: 0.6069
# Epoch 5/70
# 2272/2272 [==============================] - 27s 12ms/step - loss: 0.2772 - accuracy: 0.8857 - val_loss: 0.7912 - val_accuracy: 0.5935
# Epoch 6/70
# 2272/2272 [==============================] - 27s 12ms/step - loss: 0.2604 - accuracy: 0.8944 - val_loss: 0.7939 - val_accuracy: 0.5948
# Epoch 7/70
# 2272/2272 [==============================] - 27s 12ms/step - loss: 0.2458 - accuracy: 0.9009 - val_loss: 0.7616 - val_accuracy: 0.6342
# Epoch 8/70
# 2272/2272 [==============================] - 27s 12ms/step - loss: 0.2306 - accuracy: 0.9070 - val_loss: 1.4695 - val_accuracy: 0.5891
# Epoch 9/70
# 2272/2272 [==============================] - 32s 14ms/step - loss: 0.2197 - accuracy: 0.9136 - val_loss: 0.7400 - val_accuracy: 0.6486
# Epoch 10/70
# 2272/2272 [==============================] - 27s 12ms/step - loss: 0.2047 - accuracy: 0.9184 - val_loss: 1.0134 - val_accuracy: 0.6289
# Epoch 11/70
# 2272/2272 [==============================] - 26s 11ms/step - loss: 0.1957 - accuracy: 0.9227 - val_loss: 0.7791 - val_accuracy: 0.6422
# Epoch 12/70
# 2272/2272 [==============================] - 26s 11ms/step - loss: 0.1856 - accuracy: 0.9275 - val_loss: 0.8620 - val_accuracy: 0.6505
# Epoch 13/70
# 2272/2272 [==============================] - 28s 12ms/step - loss: 0.1737 - accuracy: 0.9326 - val_loss: 0.8651 - val_accuracy: 0.6573
# Epoch 14/70
# 2272/2272 [==============================] - 28s 12ms/step - loss: 0.1684 - accuracy: 0.9338 - val_loss: 0.7865 - val_accuracy: 0.6489
# Epoch 15/70
# 2272/2272 [==============================] - 27s 12ms/step - loss: 0.1575 - accuracy: 0.9383 - val_loss: 0.8639 - val_accuracy: 0.6055
# Epoch 16/70
# 2272/2272 [==============================] - 28s 12ms/step - loss: 0.1550 - accuracy: 0.9409 - val_loss: 0.9923 - val_accuracy: 0.6334
# Epoch 17/70
# 2272/2272 [==============================] - 27s 12ms/step - loss: 0
70
# 2272/2272 [==============================] - 27s 12ms/step - loss: 0.0562 - accuracy: 0.9804 - val_loss: 1.5840 - val_accuracy: 0.6397
# Epoch 46/70
# 2272/2272 [==============================] - 27s 12ms/step - loss: 0.0563 - accuracy: 0.9802 - val_loss: 1.3355 - val_accuracy: 0.6724
# Epoch 47/70
# 2272/2272 [==============================] - 27s 12ms/step - loss: 0.0521 - accuracy: 0.9820 - val_loss: 1.4900 - val_accuracy: 0.6481
# Epoch 48/70
# 2272/2272 [==============================] - 27s 12ms/step - loss: 0.0502 - accuracy: 0.9828 - val_loss: 1.4848 - val_accuracy: 0.6670
# Epoch 49/70
# 2272/2272 [==============================] - 27s 12ms/step - loss: 0.0499 - accuracy: 0.9823 - val_loss: 1.2766 - val_accuracy: 0.6349
# Epoch 50/70
# 2272/2272 [==============================] - 27s 12ms/step - loss: 0.0498 - accuracy: 0.9828 - val_loss: 1.1636 - val_accuracy: 0.6516

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Curves')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy Curves')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_features, test_labels)
print('Test accuracy:', test_acc)
# Out:
# 420/420 [==============================] - 2s 4ms/step - loss: 0.7144 - accuracy: 0.6945
# Test accuracy: 0.6944774985313416

# %%
# Saving the model for Future Inferences

model_json = model.to_json()
with open("model_78v4.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model_78v4.h5")

# %%
group_list=0

# %%
from sklearn.metrics import confusion_matrix
#
# Get the predictions
#
y_pred = model.predict(test_features)
y_pred =(y_pred > 0.5).astype(int)
labels = ['ASD', 'ADHD']
# Calculate the confusion matrix
#
conf_matrix = confusion_matrix(y_true=test, y_pred=y_pred)
#
# Print the confusion matrix using Matplotlib
#
fig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(conf_matrix, cmap=plt.cm.Blues, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')

ax.set_xticklabels([''] + labels)
ax.set_yticklabels([''] + labels)
ax.xaxis.set_label_coords(0.5, 1.1)

plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)

plt.title('Confusion Matrix', fontsize=20,fontweight="bold")
plt.show()
# Out:
# 420/420 [==============================] - 3s 6ms/step
# <ipython-input-51-60096e79f1c1>:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([''] + labels)
# <ipython-input-51-60096e79f1c1>:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([''] + labels)

# %% [markdown]
# # **V5**

# %%
from keras import regularizers
model = Sequential()
model.add(InputLayer(input_shape=(200, 21)))

# model.add(Conv1D(32, kernel_size=5, activation='relu'))#, kernel_regularizer=regularizers.l2(0.01))
# model.add(MaxPooling1D(pool_size=2))
# model.add(BatchNormalization())

model.add(Conv1D(64, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())

#model.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
#model.add(Dropout(0.6))

model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.6)))
model.add(Dropout(0.5))
model.add(BatchNormalization())
model.add(Dense(32, activation='sigmoid', kernel_regularizer=regularizers.l2(0.1)))
model.add(Dropout(0.8))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
  clear_session()
  model=Sequential()
  model.add(Conv1D(filters=5,kernel_size=3,strides=1,input_shape=(200,21)))#1
  model.add(BatchNormalization())
  model.add(LeakyReLU())
  model.add(MaxPool1D(pool_size=2,strides=2))#2
  model.add(Conv1D(filters=5,kernel_size=3,strides=1))#3
  model.add(LeakyReLU())
  model.add(MaxPool1D(pool_size=2,strides=2))#4
  model.add(Dropout(0.5))
  model.add(Conv1D(filters=5,kernel_size=3,strides=1))#5
  model.add(LeakyReLU())
  model.add(AveragePooling1D(pool_size=2,strides=2))#6
  model.add(Dropout(0.5))
  model.add(Conv1D(filters=5,kernel_size=3,strides=1))#7
  model.add(LeakyReLU())
  model.add(AveragePooling1D(pool_size=2,strides=2))#8
  model.add(Conv1D(filters=5,kernel_size=3,strides=1))#9
  model.add(LeakyReLU())
  model.add(GlobalAveragePooling1D())#10
  model.add(Dense(1,activation='sigmoid'))#11

# %%
plot_model(model, to_file="my_model.png", show_shapes=True)

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss']+history2.history['loss']+history3.history['loss']+history4.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss']+history2.history['val_loss']+history3.history['val_loss']+history4.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Curves')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy']+history2.history['accuracy']+history3.history['accuracy']+history4.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy']+history2.history['val_accuracy']+history3.history['val_accuracy']+history4.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy Curves')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_accuracy',
    patience=20,
    min_delta=0.001,
    mode='max',restore_best_weights=True)
